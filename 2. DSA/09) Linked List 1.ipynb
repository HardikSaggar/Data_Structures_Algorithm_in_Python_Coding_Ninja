# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
a = Node(13)
b = Node(15)
a.next = b
print(a.data)
print(b.data)
print(b)
print(a.next)
print(a.next.data)
# Out:
# 13
# 15
# <__main__.Node object at 0x0000018123D7AE20>
# <__main__.Node object at 0x0000018123D7AE20>
# 15

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def printLL(head):
    while head is not None:
        print(str(head.data)+"->",end='')
        head = head.next
    print(None)
    return
def takeInput():
    inputList = [int(ele) for ele in input().split()]
    head = None
    for currData in inputList:
        if currData == -1:
            break

        newNode = Node(currData)
        if head is None:
            head = newNode
        else:
            curr = head
            while curr.next is not None:
                curr = curr.next
            curr.next = newNode
    return head
    
head = takeInput()
printLL(head)
# Out:
# 1 2 3 4 5 -1
# 1->2->3->4->5->None

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

def printLL(head):
    while head is not None:
        print(str(head.data)+"->",end=' ')
        head = head.next
    print(None)
    return
def takeInput():
    inputList = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputList:
        if currData == -1:
            break

        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head
    
head = takeInput()
printLL(head)
# Out:
# 1 2 3 4 5 6
# 1-> 2-> 3-> 4-> 5-> 6-> None

# %% [markdown]
# #### Length of Linked List

# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None

def length(head) :
    #Your code goes here
    temp = head
    count = 0
    while temp:
        count += 1
        temp = temp.next
    return count

#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()



#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    print(length(head))

    t -= 1

# %% [markdown]
# #### Print ith Node

# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None
        
def printIthNode(head, i):
    #Your code goes here
    curr = head
    count = 0
    while curr:
        if count == i:
            print(curr.data)
        count+=1
        curr = curr.next
    return 
    
#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    i = int(stdin.readline().rstrip())
    printIthNode(head, i)

    t -= 1

# %% [markdown]
# #### Insertion

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None


def printLL(head):
    while head is not None:
        print('|'+str(head.data)+"|->",end='')
        head = head.next
    print(None)
    return
 
def length(head):
    count = 0
    while head is not None:
        count = count+1
        head = head.next
    return count

def insertAtI(head,i,data):
    if i<0 or i>length(head):
        return head
    
    count = 0
    prev = None
    curr = head
    while count<i:
        prev = curr
        curr = curr.next
        count+=1
    
    newNode = Node(data)
    if prev is not None:
        prev.next = newNode
    else:
        head = newNode
    newNode.next = curr
    
    return head
    
def takeInput():
    inputList = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputList:
        if currData == -1:
            break

        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head
    
head = takeInput()
printLL(head)
head = insertAtI(head,2,6)
printLL(head)
# Out:
# 1 2 3 4 5 -1
# |1|->|2|->|3|->|4|->|5|->None
# |1|->|2|->|6|->|3|->|4|->|5|->None

# %% [markdown]
# #### Delete node

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10 ** 6)

# Following is the Node class already written for the Linked List


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def length(head):
    count = 0
    while head is not None:
        count = count+1
        head = head.next
    return count


def deleteNodeRec(head, pos):
    if head is None:
        return head
    if pos == 0:
        return head.next

    count = 0
    temp = head
    while temp is not None and count < (pos-1):
        count += 1
        temp = temp.next

    if temp is None or temp.next is None:
        return head

    temp.next = temp.next.next

    return head


def takeInput():
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1):
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i += 1

    return head


def printLinkedList(head):

    while head is not None:
        print(head.data, end=" ")
        head = head.next

    print()


# main
t = int(stdin.readline().rstrip())

while t > 0:

    head = takeInput()
    pos = int(stdin.readline().rstrip())

    newHead = deleteNodeRec(head, pos)
    printLinkedList(newHead)

    t -= 1

# %% [markdown]
# #### Length of LL

# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None

def length_LL(head):
	if not head:
		return 0
	else:
		return 1+length_LL(head.next)

def getcount(self):
	return self.length_LL(self.head)

#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head



#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()



#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    print(length_LL(head))

    t -= 1

# %% [markdown]
# #### Insertion Recursively

# %%
 class Node:
    def __init__(self,data):
        self.data = data
        self.next = None


def printLL(head):
    while head is not None:
        print('|'+str(head.data)+"|->",end='')
        head = head.next
    print(None)
    return
 
def length(head):
    count = 0
    while head is not None:
        count = count+1
        head = head.next
    return count

     
    
def insertAtIR(head,i,data):
    if i<0:
        return head
    if i==0:
        newNode=Node(data)
        newNode.next=head
        return newNode
    if head is None:
        return None
    smallHead=insertAtIR(head.next,i-1,data)
    head.next=smallHead
    return head

def insertAtI(head,i,data):
    if i<0 or i>length(head):
        return head
    count=0
    prev=None
    curr=head
    while count<i:
        
        
        prev=curr
        curr=curr.next
        count=count+1
    newNode=Node(data)
    if prev is not None:
        prev.next=newNode
    else:
        head=newNode
    
    newNode.next=curr
    return head

def takeInput():
    inputList = [int(ele) for ele in input().split()]
    head = None
    tail = None
    for currData in inputList:
        if currData == -1:
            break

        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
    return head

    
head = takeInput()
printLL(head)
head = insertAtIR(head,2,6)
printLL(head)
head = insertAtI(head,0,9)
printLL(head)
# Out:
# 1 2 3 4 5 -1
# |1|->|2|->|3|->|4|->|5|->None
# |1|->|2|->|6|->|3|->|4|->|5|->None
# |9|->|1|->|2|->|6|->|3|->|4|->|5|->None

# %% [markdown]
# #### Deletion

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printLL(head):
    while head is not None:
        print('|'+str(head.data)+'|->',end=' ')
        head = head.next
    print(None)
    return 

def deleteLL(head,pos):
    if head is None:
        return 
    if pos == 0:
        return head.next
    
    count = 0
    temp = head
    while temp is not None and count<(pos-1):
        count += 1
        temp = temp.next
        
    if temp is None or temp.next is None:
        return head
    temp.next = temp.next.next
    
    return head
    
        
def takeInput():
    head = None
    tail = None
    inputList = [int(ele) for ele in input().split()]
    for currData in inputList:
        if currData == -1:
            break
            
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
            
    return head

head = takeInput()
printLL(head)
deleteLL(head,0)
printLL(head)
# Out:
# 1 2 3 4 -1
# |1|-> |2|-> |3|-> |4|-> None
# |1|-> |2|-> |3|-> |4|-> None

# %% [markdown]
# #### Delete Recursively

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printLL(head):
    while head is not None:
        print('|'+str(head.data)+'|->',end=' ')
        head = head.next
    print(None)
    return 

def deleteLL(head,pos):
    if head is None:
        return head
    if pos < 0:
        return head
    if pos == 0:
        return head.next
    
    dele = deleteLL(head.next,pos-1)
    head.next = dele
    
    return head
    
        
def takeInput():
    head = None
    tail = None
    inputList = [int(ele) for ele in input().split()]
    for currData in inputList:
        if currData == -1:
            break
            
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
            
    return head

head = takeInput()
printLL(head)
x = deleteLL(head,0)
printLL(x)
# Out:
# 1 2 3 4 5 -1
# |1|-> |2|-> |3|-> |4|-> |5|-> None
# |2|-> |3|-> |4|-> |5|-> None

# %% [markdown]
# ## Assignment

# %% [markdown]
# #### Find Node

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printLL(head):
    while head is not None:
        print('|'+str(head.data)+'|->',end=' ')
        head = head.next
    print(None)
    return 

def findNode(head,n):
    curr = head
    count = 0
    while curr is not None:
        if curr.data == n:
            return count
        count += 1
        curr = curr.next
    return -1
    
        
def takeInput():
    head = None
    tail = None
    inputList = [int(ele) for ele in input().split()]
    for currData in inputList:
        if currData == -1:
            break
            
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
            
    return head

head = takeInput()
printLL(head)
f = findNode(head,1)
print(f)
# Out:
# 1 2 3 4 -1
# |1|-> |2|-> |3|-> |4|-> None
# 0

# %% [markdown]
# #### Append Last to First

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
def printLL(head):
    while head is not None:
        print('|'+str(head.data)+'|->',end=' ')
        head = head.next
    print(None)
    return 

def appendLastNToFirst(haed,n):
    index = 0
    curr = head
    prev = head
    while curr is not None and n!=index:
        index+=1
        curr = curr.next
    if curr == None:
        return None
    next = curr.next
    while next is not None:
        curr = next
        next = curr.next
        prev = prev.next
    curr.next = head
    curr = prev.next
    prev.next = None
    return curr
    
        
def takeInput():
    head = None
    tail = None
    inputList = [int(ele) for ele in input().split()]
    for currData in inputList:
        if currData == -1:
            break
            
        newNode = Node(currData)
        if head is None:
            head = newNode
            tail = newNode
        else:
            tail.next = newNode
            tail = newNode
            
    return head

head = takeInput()
printLL(head)
f = appendLastNToFirst(head,2)
printLL(f)
# Out:
# 1 2 3 4 5 -1
# |1|-> |2|-> |3|-> |4|-> |5|-> None
# |4|-> |5|-> |1|-> |2|-> |3|-> None

# %% [markdown]
# #### Eliminate duplicates from LL

# %%
from sys import stdin

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None

def removeDuplicates(head) :
    if head is None or head.next is None:
        return head
    
    curr = head
    adv = curr.next
    
    while adv is not None:
        if curr.data == adv.data:
            curr.next = adv.next
            adv = curr.next
        else:
            curr = curr.next
            adv = adv.next
            
    return head

def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().strip())

while t > 0 :
    head = takeInput()

    head = removeDuplicates(head)
    printLinkedList(head)

    t -= 1
# Out:
# 1 2 3 3 3 3 -1
# |1|-> |2|-> |3|-> |3|-> |3|-> |3|-> None
# |1|-> |2|-> |3|-> None

# %% [markdown]
# #### Print Reverse

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10 ** 6)

#Following is the Node class already written for the Linked List
class Node :
    def __init__(self, data) :
        self.data = data
        self.next = None

def printReverse(head) :
    #Your code goes here
    if head is None:
        return None
    return printReverse(head.next), print(head.data,end=' ')
        


#Taking Input Using Fast I/O
def takeInput() :
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1) :
        data = datas[i]
        newNode = Node(data)

        if head is None :
            head = newNode
            tail = newNode

        else :
            tail.next = newNode
            tail = newNode

        i += 1

    return head


#to print the linked list 
def printLinkedList(head) :

    while head is not None :
        print(head.data, end = " ")
        head = head.next

    print()


#main
t = int(stdin.readline().rstrip())

while t > 0 :

    head = takeInput()
    printReverse(head)
    print()

    t -= 1
# Out:
# 1 2 3 4 5 -1
# 1 2 3 4 5 None
# 5 4 3 2 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 40>()
#      38 printLL(head)
#      39 f = reverse(head)
# ---> 40 printLL(f)
#
# Input In [49], in printLL(head)
#       6 def printLL(head):
#       7     while head is not None:
# ----> 8         print(head.data,end=' ')
#       9         head = head.next
#      10     print(None)
#
# AttributeError: 'tuple' object has no attribute 'data'

# %% [markdown]
# #### Palindrome LinkedList

# %%
from sys import stdin, setrecursionlimit
setrecursionlimit(10**5)

# Following is the Node class already written for the Linked List


class Node:
    def __init__(self, data):
        self.data = data
        self.next = None


def printLL(head):
    li = []
    while head is not None:
        li.append(head.data)
        head = head.next
    return li


def reverseLL(head):
    li = []
    while head is not None:
        li.insert(0, head.data)
        head = head.next
    return li


def isPalindrome(head):
    # Your code goes here
    if printLL(head) == reverseLL(head):
        return True
    else:
        return False

# Taking Input Using Fast I/O


def takeInput():
    head = None
    tail = None

    datas = list(map(int, stdin.readline().rstrip().split(" ")))

    i = 0
    while (i < len(datas)) and (datas[i] != -1):
        data = datas[i]
        newNode = Node(data)

        if head is None:
            head = newNode
            tail = newNode

        else:
            tail.next = newNode
            tail = newNode

        i += 1

    return head


# to print the linked list
def printLinkedList(head):

    while head is not None:
        print(head.data, end=" ")
        head = head.next

    print()


# main
t = int(stdin.readline().rstrip())

while t > 0:

    head = takeInput()

    if isPalindrome(head):
        print('true')
    else:
        print('false')

    t -= 1
# Out:
# 1 2 1
# true
